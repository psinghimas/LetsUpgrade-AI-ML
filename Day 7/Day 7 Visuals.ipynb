# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dset=pd.read_csv('C:/Users/psing/Box/LetsUpgrade AI-ML/Day 7 - Numpy Dinesh/Assignment/general_data.csv')

# %%
sns.set(style="whitegrid")

# %%
dset_att_y=dset[dset['Attrition']=='Yes']

# %%
dset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## More attrition on R&D department

# %%
sns.countplot(x="Department", hue="Attrition", data=dset)
plt.show()

# %% [markdown]
# # More attriation with employees who got less salary hike

# %%
sns.countplot(x="PercentSalaryHike", hue="Attrition", data=dset)
plt.show()

# %%
employees closer to work location under 10km has high attrition rate

# %%
sns.countplot(x="DistanceFromHome", hue="Attrition", data=dset)
plt.show()

# %% [markdown]
# # From Gender prospective no big difference in attrition of male & female

# %%
sns.countplot(x="Gender", hue="Attrition", data=dset)
plt.show()
